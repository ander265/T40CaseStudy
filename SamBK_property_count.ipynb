# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy
os.chdir('/Users/sambk/galvanize/dsi-week-zero/day-5-case-study/data/')

# %%
dta = pd.read_csv('EXTR_RPSale.csv')
dta.head(10)
# Out:
# /Users/sambk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ExciseTaxNbr   Major Minor DocumentDate  DocumentMonth  SalePrice  \
# 0       2687551  138860   110      8/21/14              8     245000
# 1       1235111  664885    40       7/9/91              7          0
# 2       2704079  423943    50     10/11/14             10          0
# 3       2584094  403700   715       1/4/13              1          0
# 4       1056831  951120   900      4/20/89              4      85000
# 5       1971467  605475    10       7/7/03              7          0
# 6       1813750   22209  9001      4/25/01              4    5755000
# 7       1813750   22209  9003      4/25/01              4    5755000
# 8       1813750   22209  9007      4/25/01              4    5755000
# ...

# %%
df = pd.DataFrame(dta, columns = ['DocumentDate'])

# %%
df['DocumentMonth'] = pd.DatetimeIndex(df['DocumentDate']).month
df['DocumentYear'] = pd.DatetimeIndex(df['DocumentDate']).year
df[:10]
# Out:
#   DocumentDate  DocumentMonth  DocumentYear  DocumentCount
# 0      8/21/14              8          2014              1
# 1       7/9/91              7          1991              1
# 2     10/11/14             10          2014              1
# 3       1/4/13              1          2013              1
# 4      4/20/89              4          1989              1
# 5       7/7/03              7          2003              1
# 6      4/25/01              4          2001              1
# 7      4/25/01              4          2001              1
# 8      4/25/01              4          2001              1
# 9      4/25/01              4          2001              1

# %%
df2008 = df.loc[df['DocumentYear'] == 2008]
df2009 = df.loc[df['DocumentYear'] == 2009]
df2010 = df.loc[df['DocumentYear'] == 2010]
df2011 = df.loc[df['DocumentYear'] == 2011]
df2012 = df.loc[df['DocumentYear'] == 2012]
df2013 = df.loc[df['DocumentYear'] == 2013]
df2014 = df.loc[df['DocumentYear'] == 2014]
df2015 = df.loc[df['DocumentYear'] == 2015]
df2016 = df.loc[df['DocumentYear'] == 2016]
df2017 = df.loc[df['DocumentYear'] == 2017]

# %%
dfs = {}
'''for year in range(2008, 2018):
        def[year] = df.loc['DocumentYear' == year, : ]'''

# %%
df['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
'''df2008['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2009['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2010['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2011['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2012['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2013['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2014['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2015['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2016['DocumentMonth'].hist(bins = 12, facecolor = 'gray')
df2017['DocumentMonth'].hist(bins = 12, facecolor = 'gray')'''
# Out:
# "df2008['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2009['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2010['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2011['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2012['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2013['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2014['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2015['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2016['DocumentMonth'].hist(bins = 12, facecolor = 'gray')\ndf2017['DocumentMonth'].hist(bins = 12, facecolor = 'gray')"

# %%
df_gb = df.groupby(['DocumentMonth']).count()
df2008_gb = df2008.groupby(['DocumentMonth']).count()
df2009_gb = df2009.groupby(['DocumentMonth']).count()
df2010_gb = df2010.groupby(['DocumentMonth']).count()
df2011_gb = df2011.groupby(['DocumentMonth']).count()
df2012_gb = df2012.groupby(['DocumentMonth']).count()
df2013_gb = df2013.groupby(['DocumentMonth']).count()
df2014_gb = df2014.groupby(['DocumentMonth']).count()
df2015_gb = df2015.groupby(['DocumentMonth']).count()
df2016_gb = df2016.groupby(['DocumentMonth']).count()
df2017_gb = df2017.groupby(['DocumentMonth']).count()

# %%
df2008_gb
# Out:
#                DocumentDate  DocumentYear  DocumentCount
# DocumentMonth
# 1                     70380         70380          70380
# 2                     72789         72789          72789
# 3                     91092         91092          91092
# 4                     92538         92538          92538
# 5                     96223         96223          96223
# 6                    100215        100215         100215
# 7                     90771         90771          90771
# 8                     93555         93555          93555
# 9                     84550         84550          84550
# 10                    86750         86750          86750
# 11                    78708         78708          78708
# 12                    91004         91004          91004

# %%
'''df2008_gb.plot()
df2009_gb.plot()'''
plt.show()
fig , ax = plt.subplots()
ax.plot(df2008_gb.index, df2008_gb.DocumentCount)
ax.plot(df2009_gb.index, df2009_gb.DocumentCount)
ax.plot(df2010_gb.index, df2010_gb.DocumentCount)
ax.plot(df2011_gb.index, df2011_gb.DocumentCount)
ax.plot(df2012_gb.index, df2012_gb.DocumentCount)
ax.plot(df2013_gb.index, df2013_gb.DocumentCount)
ax.plot(df2014_gb.index, df2014_gb.DocumentCount)
ax.plot(df2015_gb.index, df2015_gb.DocumentCount)
ax.plot(df2016_gb.index, df2016_gb.DocumentCount)
ax.plot(df2017_gb.index, df2017_gb.DocumentCount)
'''df_gb.plot(legend=None)'''
# Out:
# 'df_gb.plot(legend=None)'

# %%
plt.show()
fig , ax = plt.subplots()
ax.plot(df_gb.index, df_gb.DocumentCount)
